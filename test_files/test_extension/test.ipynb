# %%
from get_review import ShopeeReviewScraper

# %%
# 119017165.9060816021
shopid = 119017165
itemid = 9060816021
scraper = ShopeeReviewScraper(itemid, shopid)
all_reviews = scraper.get_reviews()
# Out:
# Fetched 1136 from https://shopee.vn/product/119017165/9060816021

# %%
import pandas as pd
all_reviews_df = pd.DataFrame(all_reviews)
all_reviews
# Out:
# [{'cmtid': 12593700829,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:jean\nĐúng với mô tả:đúng mô tả\nMàu sắc:xanh nhạt\n\nQuần xinh fom lên người rất đứng fom, giá săn sale nên rất hời, giao hàng nhanh, shiper thân thiện lém nha🥰🥰',
#   'modelid': 152890168755,
#   'model_name': 'H3QJeB_00_Xanh Retro,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1694779477,
#   'submit_time': 1694779477},
#  {'cmtid': 7313300632,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Giao nhanh nhoaaaa ! Màu quần giống hình rất ưng. Mặc với áo thun trắng siêu hợp. Quần không có chỉ thừa. Đường may cũng rất cẩn thận ! NCL nên mua nha mn !!!',
#   'modelid': 55673868568,
#   'model_name': 'Xanh,Size 27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1643113786,
#   'submit_time': 0},
#  {'cmtid': 14849843225,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:ok\nMàu sắc:ok\nChất liệu:ok\n\nHàng được shop đóng gói cực kì cẩn thận, sử dụng tốt, chất lượng tốt và rất đáng mua',
#   'modelid': 193100311375,
#   'model_name': 'DaQJeR_00_Wash Vàng,31',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1712720120,
#   'submit_time': 1712720120},
#  {'cmtid': 14114412437,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:ddepj\nMàu sắc:chuẩn màu rồi quá đẹp\nChất liệu:vài bò\n\nGiao hàng khá nhanh, đẹp\nMình cao 1m71 50kg mặc sizeL thì ôk vừa \nBạn nào muốn mặc dài hơn thì lấy size xl nhé',
#   'modelid': 193100311374,
#   'model_name': 'DaQJeR_00_Wash Vàng,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1707134132,
#   'submit_time': 1707134132},
#  {'cmtid': 13976128683,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:toots\nĐúng với mô tả:đúng\nMàu sắc:đẹp\n\nSản phẩm đúng chất lượng săn sale giá rẻ đáng để mua nhé ae nên mua nha mua',
#   'modelid': 152890168751,
#   'model_name': 'DaQJeR_00_Wash Nhạt,34',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706057472,
#   'submit_time': 1706057472},
#  {'cmtid': 11943364510,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:Xám đen\nĐúng với mô tả:Đúng\nChất liệu:Jean mềm\n\nMua lần 2 cho nữ mặc nha, size 27 dưới m6 1 xí mặc vẫn ngon lành cành đào luôn á',
#   'modelid': 55673868568,
#   'model_name': 'H1QJeB_C3_Xám,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1688900514,
#   'submit_time': 0},
#  {'cmtid': 14062788390,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đen wash\nĐúng với mô tả:Đúng\nChất liệu:vải\n\nQuần về đẹp lắm nha mng, màu đẹp như hình.\nShop hỗ trợ đổi trả rất nhiệt tình luôn.\nNên mua nha !',
#   'modelid': 152890168757,
#   'model_name': 'DaQJeR_00_Wash Đen,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706763720,
#   'submit_time': 1706763720},
#  {'cmtid': 13793746659,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng\nMàu sắc:y hình\nChất liệu:jean co giãn\n\nmình mua luon cả ship chỉ 144k thoi nhma chất lượng khỏi phải bàn r',
#   'modelid': 152890168758,
#   'model_name': 'DaQJeR_00_Wash Đen,30',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1704562330,
#   'submit_time': 1704562330},
#  {'cmtid': 14015775500,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:jean\nĐúng với mô tả:chuẩn như mô tả\nMàu sắc:đen\n\nQuần đẹp xuất sắc y chang hình mẫu, chất lượng mà giá ổn, sẽ tiếp tục ủng hộ',
#   'modelid': 152890168753,
#   'model_name': 'DaQJeR_00_Wash Đen,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706364323,
#   'submit_time': 1706364323},
#  {'cmtid': 12983731246,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Đúng với mô tả:dung\nMàu sắc:ghi\nChất liệu:jean\n\nHàng cũng được. Giá cả hợp lí. Chất lượng bình thường. Các bạn ủng shop shop nhé. Tiền nào quần đó các bạn ơi.',
#   'modelid': 152890168756,
#   'model_name': 'H3QJeB_00_Xanh Rêu,29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1698183173,
#   'submit_time': 1698183173},
#  {'cmtid': 15463492690,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:jean\nĐúng với mô tả:đúng\nMàu sắc:có wash vàng\n\nHàng giao tầm 3 ngày ngoài nội thành ạ. Mình mua shop nhiều, nhưng cũng tuỳ vào loại sản phẩm mà kích cỡ có khác. Giá cũng oke lắm ạ. Mọi người có thể tham khảo thử ạ',
#   'modelid': 152890168750,
#   'model_name': 'DaQJeR_00_Wash Nhạt,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1717984839,
#   'submit_time': 1717984839},
#  {'cmtid': 12883773824,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:ok\nChất liệu:ok\nMàu sắc:ok\n\nThì ra là thế nào cx có thể làm được điều này đã được sự quan tâm đến việc nhóm mà không cần phải có nội dung của môn học mà mik',
#   'modelid': 152890168768,
#   'model_name': 'DaQJeR_00_Wash Đen,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1697365793,
#   'submit_time': 1697365793},
#  {'cmtid': 13118134848,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng với mô tả\nMàu sắc:xanh wash\nChất liệu:jean\n\nShop phục vụ tốt lắm ạ, mình đặt nhầm size, nt cho shop hỗ trợ nhanh và nhiệt tình nữa. Rất có tâm luôn. Chất lượng khỏi bàn nhé mn ơi, vải mặc ấm áp, form chuẩn hàng cao cấp ạ Hàng tốt giao hàng nhanh lắm nha quá tuyệt vời luôn đáng tiền lắm nha. Hàng phải nói là rất ư là đẹp rẽ bền ủng hộ bấy lâu nay.',
#   'modelid': 193100311379,
#   'model_name': 'DaQJeR_00_Wash Đậm,27',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1699296397,
#   'submit_time': 1699296397},
#  {'cmtid': 13307156966,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:như mô tả\nChất liệu:vải rin\nMàu sắc:xanh\n\nĐúng như mô tả, vải đẹp, rẻ . Nên mua. Đúng Sai. Giao hàng nhanh chóng, đóng gói cẩn thận. Cho shop 5 sao',
#   'modelid': 203100311196,
#   'model_name': 'DaQJeR_00_Wash Đậm,36',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1700716567,
#   'submit_time': 1700716567},
#  {'cmtid': 13650671174,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Thiết kế chất lượng cao và thoải mái, đồng thời tạo nên phong cách thời trang độc đáo. Chất liệu chắc chắn, vừa vặn tốt và giúp tạo nên hình dáng thon gọn. Tôi rất hài lòng với sự thoải mái và phong cách mà nó mang lại.',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Wash Đen,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1703308320,
#   'submit_time': 1703308320},
#  {'cmtid': 5321406126,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất lượng sản phẩm tuyệt vời. Đóng gói sản phẩm rất đẹp và chắc chắn. Thời gian giao hàng nhanh chóng. Shop phục vụ tốt. Rất đáng tiền.',
#   'modelid': 55673868571,
#   'model_name': 'Xanh,Size 35',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1625820644,
#   'submit_time': 0},
#  {'cmtid': 14894036461,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:quần đúng y hình\nChất liệu:vai jean mềm mịn mát\nMàu sắc:chuẩn hình\n\nLần đầu tiên mình mới mua được cái quần jean nam hàng chợ rẻ mà lại mặc OK như vậy\nY như hình , shop uy tín\nMọi người nên mua ủng hộ\nChúc shop Hồng phát',
#   'modelid': 152890168767,
#   'model_name': 'DaQJeR_00_Wash Đen,34',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1713233681,
#   'submit_time': 1713233681},
#  {'cmtid': 13557086822,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:ok\nĐúng với mô tả:ok\nMàu sắc:ok\n\nShop tư vấn sz vừa in luôn đúng mê. Vừa là thích rồi mà quần mặc lên còn đẹp nữa mình mua cho ngiu mà thấy mặc lên thoải mái mà cũng vừa vặn nữa. Giá hời ntn thì phải ủng họp dài thuiii',
#   'modelid': 152890168766,
#   'model_name': 'DaQJeR_00_Wash Đen,31',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1702636705,
#   'submit_time': 1702636705},
#  {'cmtid': 12501927886,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đặt thử xem thế nào nhưng thật sự quá là ưng cái bụng,quần dầy dặn from đẹp,đường may đẹp,với giá cả hợp lí như vậy thì sẽ luôn ủng hộ shop lâu dài.',
#   'modelid': 55673868562,
#   'model_name': 'H1QJeB_C3_Xám,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1694058977,
#   'submit_time': 1694058977},
#  {'cmtid': 13938361165,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đúng\nĐúng với mô tả:đúng\nChất liệu:đúng\n\nSản phẩm rất xinh đẹp tuyệt vời, tôi không thể trông đợi gì hơn. Cảm ơn nhà cung cấp, nhà sản xuất, cảm ơn người bán hàng, cảm ơn sàn thương mại điện tử, cảm ơn người vận chuyển để tôi có cơ hội dùng sản phẩm tốt như thế này. Hàng đóng gói rất đẹp. Quả nhiên người bán đã gửi gắm rất nhiều tâm tư và tình cảm trong lúc gói hàng. Hộp không có dấu hiệu bị móp, chứng tỏ bộ phận vận chuyển đã nâng như nâng trứng, hứng như hứng hoa. Xin nghiêng mình cảm ơn vì tất cả. Thời gian vận chuyển rất hợp lí. Tôi đã đặt hàng với tâm thế hào hứng chờ đợi để được trải nghiệm sản phẩm và tôi không hề bị chờ mỏi cổ. Có thể thấy bên vận chuyển không quản ngại thời tiết và đường xá xa xôi để đưa sản phẩm cho tôi trong thời gian ngắn nhất',
#   'modelid': 193100311374,
#   'model_name': 'DaQJeR_00_Wash Vàng,28',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705723752,
#   'submit_time': 1705723752},
#  {'cmtid': 12160477679,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đen\nChất liệu:jeans\nĐúng với mô tả:ok\n\nQuần chất jeans ok, dày dặn nha, có điều mình tưởng đai quần là đai chun mà không phải',
#   'modelid': 152890168762,
#   'model_name': 'DaQJeR_00_Đen,36',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1691035572,
#   'submit_time': 0},
#  {'cmtid': 13522088867,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:bò jeans\nĐúng với mô tả:đúng\nMàu sắc:đen\n\nQuần đẹp lắm nhưng có lẽ là mình nên tăng size nếu bụng to nhé. Mình 80kg mặc size 34 bụng vừa khít. Nếu tăng lên 36 chắc sẽ thoải mái hơn',
#   'modelid': 115789933479,
#   'model_name': 'DaQJeR_00_Đen,34',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1702421552,
#   'submit_time': 1702421552},
#  {'cmtid': 13258993282,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Mua được quần rẻ mà chất cũng thích hôm trước lấy 1 quần màu đen giờ lấy thêm quần màu xang nhạt nói chung rất thích mặc vừa in luôn',
#   'modelid': 152890168756,
#   'model_name': 'DaQJeR_00_Wash Nhạt,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1700318039,
#   'submit_time': 1700318039},
#  {'cmtid': 11978087427,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Đúng với mô tả:jean\nMàu sắc:đen\nChất liệu:jean\n\nQuần oke, thời gian giao hàng cũng oke, nói chung ổn ( ảnh và video chỉ mang tính chất nhận xu )',
#   'modelid': 152890168759,
#   'model_name': 'DaQJeR_00_Đen,35',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1689181453,
#   'submit_time': 0},
#  {'cmtid': 14856745846,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': '‼️CBGD MỸ DUYÊN NHÂY REFUND, NÓI DỐI BUYER LÀ BẠN GIỮ TIỀN HỘ OFF FB ÔN THI NHƯNG THẬT RA ĐÃ XÀI HẾT TIỀN‼️\nhttps://www.facebook.com/profile.php?id=61556028420287&mibextid=LQQJ4d\n\nchắc hẳn ai có theo dõi group thì cách đây 2 tháng trước group mình có xôm xao về vụ việc nguồn hình ảnh des của qtv và người đứng đầu trong việc kịch liệt đăng 1001 bài “nghi vấn” tố qtv đủ thứ trên trời dưới biển không ai khác ngoài cái tên quen thuộc MỸ DUYÊN\n\n📎với những tội lỗi MD gây ra sau vụ việc đó thì cổ có dấu hiệu mất tích 1 thời gian để mọi người phải đăng bài kiếm cổ thì bây giờ cổ đã quay trở lại tẩy trắng bằng cách share 1 chiếc deal siu to khổng lồ, ngon nghẻ và dắt mũi ctoi như 1 con bò🤡\n\n📎sau bài cbgd ngày hôm qua của t có đăng (mọi ng có thể bấm vào bài cbgd của t đăng để xem chi tiết MD đã share deal và quằng với t như nào nhe😊) thì có 1 bạn đã ib cho t và nói bạn là người giữ tiền hộ cho MD, được biết số tiền mà chủ deal hoàn cọc cho group tụi t đã được MD xài hết ngay trong hôm đó và bạn đã nói dối với tụi t là bạn giữ tiền off fb để ôn thi nên bây giờ phải lấy tiền túi của bạn ra để rf nên tgian rf sẽ khá lâu (mọi ng bấm vào ảnh để xem cho dễ hơn nhe chứ viết cap dài sợ mọi ng lừi đọc🥹)\n\nLINK BÀI CBGD HQUA, có chi tiết câu chuyện nhây rf 13 ngày : https://www.facebook.com/share/p/yhxCg3PBEQiNvYU7/?mibextid=ƯC7FNe',
#   'modelid': 152890168750,
#   'model_name': 'DaQJeR_00_Wash Nhạt,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1712806021,
#   'submit_time': 1712806021},
#  {'cmtid': 7937415122,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'tớ cao 1m55 và chọn size 28 thì mang vào vừa luôn không ngắn đến mắt cá chân đâu nhưng dài kiểu mang giày rất đẹp không lòng thòng, quần rất đẹp như hàng hiệu',
#   'modelid': 115789933477,
#   'model_name': 'Xanh LV_3S,Size 28',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1648892849,
#   'submit_time': 0},
#  {'cmtid': 13532589898,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng\n\nquần đẹp,mình cao m73 58kg mặc size 30 vừa, bạn nào muốn mặc vừa thì chọn size 29 tại mình thích mặc rộng',
#   'modelid': 152890168750,
#   'model_name': 'DaQJeR_00_Wash Nhạt,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1702477626,
#   'submit_time': 1702477626},
#  {'cmtid': 9020014571,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:Tốt\nĐúng với mô tả:hài lòng\n\nChất lượng sản phẩm tuyệt vời hàng đúng với mô tả shop phục vụ tốt và hài lòng với shop',
#   'modelid': 55673868564,
#   'model_name': 'DaQJeR_02_Xanh,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1658240599,
#   'submit_time': 0},
#  {'cmtid': 13680561719,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:tốt\n\nMàu bên ngoài rất đẹp, shop tư vấn nhiệt tình nên chọn size rất chuẩn, giao hàng nhanh. Mn nên mua ủng hộ shop nha.',
#   'modelid': 152890168757,
#   'model_name': 'DaQJeR_00_Wash Đen,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1703585387,
#   'submit_time': 1703585387},
#  {'cmtid': 12426632176,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng\nMàu sắc:đen\nChất liệu:jean\n\nSản phẩm chất lượng, giá cả ổn áp, chất đẹp, giao hàng nhanh, shop phục vụ rất tốt, shipper thân thiện.....',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Đen,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1693365841,
#   'submit_time': 1693365841},
#  {'cmtid': 14398020773,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng với mô tả\nChất liệu:tốt\nMàu sắc:xanh, đẹp, trẻ trung\n\nGiá hời mà đc cái quần xịn như này thì không còn gì phải chê',
#   'modelid': 152890168765,
#   'model_name': 'DaQJeR_00_Wash Nhạt,31',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1709565700,
#   'submit_time': 1709565700},
#  {'cmtid': 8510666516,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:chất niệu rày rặn , ko có chỉ thừa\nMàu sắc:màu đen ,rất đẹp\nĐúng với mô tả:sản phẩm đúng với mô tả của shopp\n\nGiao hàng rất nhanh',
#   'modelid': 152890168758,
#   'model_name': 'DaQJeB_04_Đen·,Size 30',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1653801292,
#   'submit_time': 0},
#  {'cmtid': 12927559370,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:Đen wash\nĐúng với mô tả:đún\nChất liệu:jean\n\nMình mua ở đây 2 đến 3 lần rồi rất là hài lòng luôn ạ giá rẻ chất quần đẹp nên mua nhứ cả nhà ơi',
#   'modelid': 152890168766,
#   'model_name': 'DaQJeR_00_Wash Đen,31',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1697698968,
#   'submit_time': 1697698968},
#  {'cmtid': 12633307304,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:oke\nMàu sắc:giống hình\nChất liệu:oke\n\nSản phẩm mua về mặc lên rất ưng, chất vải cứng vừa phải, thời gian giao hàng nhanh, phù hợp với giá tiền',
#   'modelid': 152890168754,
#   'model_name': 'H3QJeB_00_Xanh Retro,32',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1695184125,
#   'submit_time': 1695184125},
#  {'cmtid': 11569186735,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đẹpt\nMàu sắc:ghi đen\nChất liệu:tốt\n\nĐã nhận được hàng . Shop giao hàng nhanh , chất liệu tốt đúng form đúng dáng giống ảnh mẫu . Mọi người nên mua nhé',
#   'modelid': 55673868570,
#   'model_name': 'H3QJeB_C3_Xám,31',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1684889985,
#   'submit_time': 0},
#  {'cmtid': 14185904984,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng\nMàu sắc:đen xám\nChất liệu:jean\n\nSản phẩm đúng với mô tả vải đẹp không bị lỗi hàng nguyên vẹn mọi người yên tâm khi mua hàng nhé 👍',
#   'modelid': 157132899613,
#   'model_name': 'H1QJeR_C3_Xám Đen,29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1707806591,
#   'submit_time': 1707806591},
#  {'cmtid': 11914352152,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'DƯỠNG CHẤT NHÂN SÂM DƯỠNG DA CHỐNG LÃO HÓA\n\nDưới ánh nắng gay gắt của mùa hè, làn da sẽ bị lão hóa nhanh gấp 2 lần nếu như không được chăm sóc kỹ và đúng cách.\n\nGiàu dưỡng chất từ Nhân Sâm quý giá, kết cấu mỏng nhẹ dễ tán và ôn trọn lấy làn da, cùng hương thơm thảo mộc đặc trưng, chu trình dưỡng da 3 bước từ Sulwhasoo đơn giản, thoải mái nhưng mang lại hiệu quả chống lão hóa tối ưu.\n\nGồm First Care Activating Serum, Tinh Chất Nhân Sâm Concentrated Ginseng Renewing Serum và Kem Dưỡng Nhân Sâm Concentrated Ginseng Renewing Cream, bộ 3 mang đến các tác động then chốt giúp làn da luôn khỏe mạnh trong những ngày hè: cung cấp độ ẩm, tăng cường hàng rào bảo vệ da, duy trì độ đàn hồi và hạn chế tình trạng chảy xệ của các nếp nhăn.\n\n#SulwhasooVN',
#   'modelid': 55673868563,
#   'model_name': 'H1QJeB_C3_Xám,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1688629463,
#   'submit_time': 0},
#  {'cmtid': 12987499564,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Tuyệt vời Mua bộ YẾN này là đầy đủ các bước dưỡng da ăn Tết luôn ạ: Bộ kim cương tổ yến gồm 1 kem yến ngày 1 kem yến đêm, 1 tẩy da mặt, 1 gói serum, 1 sữa rửa mặt detox thải đọ^c da, 1 chai serum trắn da, 1 nạ đắp mặt chỉ 380k ạ\n👉mua kèm bộ gia đình gồm:1 chai nước hoa,1 chai sữa tắm,1 chai body \n👉mua kèm set serum nhau thai cừu 3 chai chỉ 59k ạ \n👉MUA KÈM SỮA RỬA MẶT táo đỏ TRỊ MỤN 49K\n👉mua kèm chai sữa tắm trắn chanh 45k 650ml \n👉MUA KÈM BODY CHANH 35k\nchỉ có 79k ạ\n❤️Khách sỉ ib Múi tv ưu đãi thêm cho khách ạ\n❤️Mua 2 bộ miễn ship\n❤️Không lấy quà giảm giá thêm\n❤️khách muốn đổi quà ib Múi ạ\nCác sản phẩm khác của nhà Múi c iu mua thêm để được miễn ship tặng thêm quà ạ :\n#Set_kem_chống_nắng_lớn_265k (100g tặng thêm tuýp nhỏ 50g)\n#kem_cừu_ngày_320k tặng kèm thêm tẩy da mặt bên trong hộp kem\n#kem_cừu_đêm_320k tặng kèm thêm tẩy da mặt bên trong hộp kem\n#Tảo_biển_299k tặng kèm thêm sữa rửa mặt thải độc mini bên trong hộp tảo\n#nạ_ngủ_collagen_310k\n👉KIỂM TRA HÀNG TRƯỚC KHI NHẬN có thẻ bảo hành và keo đỏ, có tem chống hàng gi.ả MỚI NHẬN HÀNG Ạ ❤️',
#   'modelid': 152890168757,
#   'model_name': 'DaQJeR_00_Wash Đen,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1698214847,
#   'submit_time': 1698214847},
#  {'cmtid': 13902086044,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:ok\nChất liệu:kk\nMàu sắc:ok\n\nRồi em sẽ gặp được thôi, một người thoải mái viết về em trên mạng xã hội.\nChẳng ngần ngại post cả ảnh em lên, đặt ảnh đại diện là em mãi chẳng muốn thay đổi.\nStory anh ấy luôn là những vẻ mặt đáng yêu nhất của em.\nChắc chắn em sẽ tìm được một người như vậy....\n\n“Không phải là người kiên nhẫn, nhưng cũng đã đợi một người rất lâu.”',
#   'modelid': 115789933485,
#   'model_name': 'DaQJeR_00_Đen,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705425533,
#   'submit_time': 1705425533},
#  {'cmtid': 14082759017,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': '😄Thời gian vận chuyển rất hợp lí. Tôi đã đặt hàng với tâm thế hào hứng chờ đợi để được trải nghiệm sản phẩm và tôi không hề bị chờ mỏi cổ. Có thể thấy bên vận chuyển không quản ngại thời tiết và đường xá xa xôi để đưa sản phẩm cho tôi trong thời gian ngắn nhất.',
#   'modelid': 152890168749,
#   'model_name': 'DaQJeR_00_Wash Nhạt,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706894825,
#   'submit_time': 1706894825},
#  {'cmtid': 11384745405,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:oke\nĐúng với mô tả:đúng\nMàu sắc:đen\n\nHàng oke lắm anh em ạ. Rẻ mà chất lượng nha. Hình ảnh này up cho vui.',
#   'modelid': 152890168753,
#   'model_name': 'DaQJeR_00_Đen,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1682861722,
#   'submit_time': 0},
#  {'cmtid': 14052041833,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đug\nMàu sắc:xanh vàng\nChất liệu:vải bò\n\nH@  chỉ mang tc nhận xu thôi , nhạn quần ưng ý lắm quần đẹp lém nha mọi ng yên tám mua n',
#   'modelid': 203100311194,
#   'model_name': 'DaQJeR_00_Wash Vàng,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706680542,
#   'submit_time': 1706680542},
#  {'cmtid': 13791648766,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'quần đẹp tiếc mình hơi lùn cao chọn size nhỏ nhất mà muốn che hết bàn chân cao thêm 5cm nữa ok giá hợp lý phết',
#   'modelid': 152890168768,
#   'model_name': 'DaQJeR_00_Wash Đen,27',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1704546222,
#   'submit_time': 1704546222},
#  {'cmtid': 13437091827,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đen\nĐúng với mô tả:ok\nChất liệu:vải\n\nAlonso và có những ai đã thấy thùy dương vật vào đến giờ bận tâm đến những bạn gái em mang thai và cô văn nhắc nhở nhưng giờ đã',
#   'modelid': 152890168758,
#   'model_name': 'DaQJeR_00_Wash Đen,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1701768926,
#   'submit_time': 1701768926},
#  {'cmtid': 14411423087,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng\nMàu sắc:chuẩn\nChất liệu:tốt\n\nGiao hàng nhanh, shop tư vấn nhiệt tình, giá thành lại rẻ đáp ứng được mọi nhu cầu của sinh viên và học sinh . Mình đã mua rất nhiều lần, lần sau sẽ ủng hộ nhiều hơn 🌹🌹🌹',
#   'modelid': 152890168756,
#   'model_name': 'DaQJeR_00_Wash Nhạt,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1709657906,
#   'submit_time': 1709657906},
#  {'cmtid': 11170623692,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Mình rất ưng ý khi nhận sản phẩm. Chất vải dày dặn, đường may cẩn thận, từ màu sắc đến kiểu dáng đều đúng như ảnh chụp. Giá thành rẻ so với chất lượng. Giao hàng siêu nhanh. Sẽ tiếp tục ủng hộ shop lâu dài.',
#   'modelid': 115789933484,
#   'model_name': 'H1QJeB_C3_Xanh Sky,29',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1680615225,
#   'submit_time': 0},
#  {'cmtid': 12985302253,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đúng\nĐúng với mô tả:chuẩn\nChất liệu:chuẩn\n\nSản phẩm tốt giao hàng nhanh đúng hàng chất lượng shop nhiệt tình uy tính hình ảnh chỉ mang tính chất nhận xu vì ch kịp chụp ạ, cho shop 5sao',
#   'modelid': 152890168749,
#   'model_name': 'H3QJeB_00_Xanh Rêu,28',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1698201386,
#   'submit_time': 1698201386},
#  {'cmtid': 10894322142,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:jean\nMàu sắc:xanh\nĐúng với mô tả:đúng\n\nShop chuẩn bị hàng và giao hàng nhanh. Vải đẹp, dày, quá ổn so với giá. Sẽ ủng hộ shop',
#   'modelid': 115789933483,
#   'model_name': 'H1QJeB_C3_Xanh Sky,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1677734808,
#   'submit_time': 0},
#  {'cmtid': 11921811020,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Shop phục vụ khá chu đáo,hàng đẹp, vải đẹp,ưng lắm luôn mng ạ shipper giao khá nhanh shop uy tín sẽ ủng hộ shop lần sau ak',
#   'modelid': 115789933482,
#   'model_name': 'H1QJeB_C3_Xanh Nhạt,31',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1688702639,
#   'submit_time': 0},
#  {'cmtid': 13875295540,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:jean\nĐúng với mô tả:chuẩn\nMàu sắc:chuẩn\n\nHàng rất ok giao hàng nhanh đóng gói rất cẩn thận.Rất ưng nha 👍hình ảnh chỉ mang tính chất nhận xu 👏',
#   'modelid': 115789933478,
#   'model_name': 'DaQJeR_00_Đen,30',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705216461,
#   'submit_time': 1705216461},
#  {'cmtid': 14903508159,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:vải bò\nMàu sắc:xanh vàng\n\nSản phẩm okie mk mua cho bn, màu sắc đẹp chất liệu khá thoáng lên dáng đẹp sẽ mua lại',
#   'modelid': 203100311197,
#   'model_name': 'DaQJeR_00_Wash Vàng,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1713323250,
#   'submit_time': 1713323250},
#  {'cmtid': 5222668098,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quần đẹp thật sự, giống trong ảnh, lên form rất đẹp\nShop tư vấn rất nhiệt tình và trả lời tin nhắn rất nhanh\nXứng đáng 5 saoooo <3',
#   'modelid': 55673868563,
#   'model_name': 'Xanh,Size 30',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1624951409,
#   'submit_time': 0},
#  {'cmtid': 13580549006,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:vải\nMàu sắc:đen\nĐúng với mô tả:chuẩn với mô tả\n\nChất lượng vải đảm bảo, đúng với mẫu mã, giao hàng nhanh, đóng hàng đep',
#   'modelid': 152890168753,
#   'model_name': 'DaQJeR_00_Wash Đen,29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1702793820,
#   'submit_time': 1702793820},
#  {'cmtid': 12812530366,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:99%\nChất liệu:không biết\nMàu sắc:đen trắng\n\nSản phẩm ổn mua đến lần thư 3 rồi vẫn ưng nha\nĐóng gói chắc chắn giao hàng đến cũng nhanh nữa \nHình ảnh và video chỉ mang tính nhận xu',
#   'modelid': 152890168758,
#   'model_name': 'DaQJeR_00_Wash Đen,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1696845705,
#   'submit_time': 1696845705},
#  {'cmtid': 14082113817,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đúng\nĐúng với mô tả:yep\nChất liệu:jean\n\nQuá tuỵtttt, đồ shop khỏi bàn nha, chất đẹp dáng chuẩn form đẹp, 10d ko có nhưngggggghgggggggg. Hình ảnh video mang tính chất kím xu\nM72-56kg size 30',
#   'modelid': 152890168758,
#   'model_name': 'DaQJeR_00_Wash Đen,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706888185,
#   'submit_time': 1706888185},
#  {'cmtid': 13973749113,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:dden\nChất liệu:jean\nĐúng với mô tả:đúng\n\nĐồ đẹp , lần đầu mua shop nhưng mà ưng nha 10000điểm cho shop , đi hàng nhanh , để đúng đồ , chất from lên đều đẹp',
#   'modelid': 152890168766,
#   'model_name': 'DaQJeR_00_Wash Đen,31',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706017920,
#   'submit_time': 1706017920},
#  {'cmtid': 6602724800,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Hàng đẹp chất lượng cao \nGiao hàng rất đúng . Đẹp miễn chê luôn \nĐồ xinh xỉu luôn . Mong shop giao hàng nhanh hơn tý nữa là OK . Hình chỉ mang t/c lấy xu',
#   'modelid': 55673868566,
#   'model_name': 'Xanh,Size 34',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1636980147,
#   'submit_time': 0},
#  {'cmtid': 14054326949,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:ok\nChất liệu:jean\nMàu sắc:đen wash\n\nShop tư vấn size chuẩn. Màu ở ngoài mình thấy còn đẹp hơn trên ảnh nữa. Săn sale được giá rẻ quá hời luôn',
#   'modelid': 152890168758,
#   'model_name': 'DaQJeR_00_Wash Đen,30',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706693179,
#   'submit_time': 1706693179},
#  {'cmtid': 15060380536,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:ổn\nMàu sắc:đúng\nĐúng với mô tả:đúng\n\nnhận hàng về mình mặc thử vừa in luon, hàng ổn với giá tiền,giao nhanh, nói chung là đáng mua',
#   'modelid': 152890168768,
#   'model_name': 'DaQJeR_00_Wash Đen,27',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1714659754,
#   'submit_time': 1714659754},
#  {'cmtid': 14105136682,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:oke nah\nMàu sắc:ddepj nha\nĐúng với mô tả:dày\n\nEm mình mặc vừa in lun, mình nt dục shop\nShop tận tâm quá chừng hàng tốt nx',
#   'modelid': 152890168768,
#   'model_name': 'DaQJeR_00_Wash Đen,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1707066945,
#   'submit_time': 1707066945},
#  {'cmtid': 10884951221,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đen\nĐúng với mô tả:đúng\nChất liệu:tốt\n\nQuần của shop đẹp mê li lun , vận chuyển giao hàng khá là nhanh sẽ ủng hộ shop dài dài',
#   'modelid': 152890168764,
#   'model_name': 'DaQJeR_00_Đen,33',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1677637136,
#   'submit_time': 0},
#  {'cmtid': 14221049672,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đen\nChất liệu:jean\nĐúng với mô tả:đúng\n\nMàu đẹp nha, giá này thì chất oke nhà, giao hàng nhanh, ổn có thể quay lại mua tiếp ạ',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Wash Đen,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1708158692,
#   'submit_time': 1708158692},
#  {'cmtid': 13691484901,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:dung\nMàu sắc:wash nhạt\nChất liệu:vải\n\nNhận quần xong rất ưng ý. Giá cả rẻ nhưng chất lượng rất oce. Sẽ ủng hộ shop thêm',
#   'modelid': 152890168751,
#   'model_name': 'DaQJeR_00_Wash Nhạt,34',
#   'filter': 3,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1703677172,
#   'submit_time': 1703955015},
#  {'cmtid': 11919439113,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:ttoot\nĐúng với mô tả:chuẩn\nMàu sắc:y hình\n\nHình ảnh và video chỉ mang tính chất nhận xu, đóng gói cản thận hàng y hình',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Đen,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1688666880,
#   'submit_time': 0},
#  {'cmtid': 12628534524,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:đẹp\nĐúng với mô tả:đúng\nMàu sắc:đẹp\n\nQuần xịn xò lắm nhaaa , mua cho anh ny mà anh ny cũng khen quá chừng',
#   'modelid': 152890168751,
#   'model_name': 'H3QJeB_00_Xanh Retro,34',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1695124126,
#   'submit_time': 1695124126},
#  {'cmtid': 11261384360,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:ok\nMàu sắc:khá\nĐúng với mô tả:đúng\n\nChất vải dày dặn nhưng khá mềm tay, phom quần ok. Hài lòng, để 5 sao cho shop',
#   'modelid': 115789933483,
#   'model_name': 'H1QJeB_C3_Xanh Sky,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1681390403,
#   'submit_time': 0},
#  {'cmtid': 5167628885,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quần đẹp rẻ hơn rất nhiều so với chất lượng, ncl mình ưng shop vừa rẻ vừa chất lượng giao hàng nhanh đóng gói kĩ.',
#   'modelid': 55673868565,
#   'model_name': 'Xanh,Size 33',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1624440259,
#   'submit_time': 0},
#  {'cmtid': 14299077631,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Cơ hội sở hữu sản phẩm Bình nước thủy tinh bọc nhựa giữ nhiệt 450ml có ống hút dây đeo tiện lợi, nắp thú dễ thương được giảm 30%! Chỉ còn ₫49.000. Mua ngay trên Shopee! https://shp.ee/k1kcumeCơ hội sở hữu sản phẩm Bình nước thủy tinh bọc nhựa giữ nhiệt 450ml có ống hút dây đeo tiện lợi, nắp thú dễ thương được giảm 30%! Chỉ còn ₫49.000. Mua ngay trên Shopee! https://shp.ee/1h0bzrw',
#   'modelid': 193100311374,
#   'model_name': 'DaQJeR_00_Wash Vàng,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1708818945,
#   'submit_time': 1708818945},
#  {'cmtid': 13940437469,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng\nChất liệu:tốt\nMàu sắc:đen\n\n[QC] Tổng đài Thông tin Kinh tế - Xã hội Viettel hướng dẫn cách đăng ký hộ chiếu online nhanh chóng và đơn giản nhất. Quý khách vui lòng gọi 1068 (từ số điện thoại Viettel) hoặc 0281068 (từ số điện thoại mạng khác). Giá cước: 3.000đ/p. Từ chối QC, soạn TC3 gửi 199.',
#   'modelid': 152890168766,
#   'model_name': 'DaQJeR_00_Wash Đen,31',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705735369,
#   'submit_time': 1705735369},
#  {'cmtid': 12330673262,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:dheh\nĐúng với mô tả:tốt\nChất liệu:đẹp\n\nMạng xã hội không chỉ là nơi để giải trí mà còn là nơi để lưu giữ những kỷ niệm đẹp của gia đình. Nếu bạn muốn thể thể hiện sự trân trọng gia đình bằng những caption hay về cuộc sống gia đình thì hãy tham khảo những câu cap hay sau:',
#   'modelid': 55673868569,
#   'model_name': 'H1QJeB_C3_Xám,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1692455224,
#   'submit_time': 1692455224},
#  {'cmtid': 7337655817,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Mình mua ở shop 2 lần rồi và rất hài lòng về sản phẩm bên shop , chất vãi mịn chữ thêu đẹp . Siêu siêu ưng luôn nha . Có lẽ phải ủng hộ shop nhiều hơn rồi hihi',
#   'modelid': 55673868562,
#   'model_name': 'Xanh,Size 28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1643344654,
#   'submit_time': 0},
#  {'cmtid': 7868652324,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'quần form đẹp, chất vải ok so vs giá tiền. Tuy nhiên mng mua cần mua lớn hơn 1 size lên form mới chuẩn nhé. Chúc shop buôn may bán đắt ♥️',
#   'modelid': 55673868565,
#   'model_name': 'Xanh SPO,Size 33',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1648283429,
#   'submit_time': 0},
#  {'cmtid': 13433312995,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:mau đen\nChất liệu:size 28 vừa luôn\nĐúng với mô tả:đúng mô tả\n\nƯng lắm shop nhé . Con mình rất thích . Giá hợp lý . Mọi người nên mua nha',
#   'modelid': 115789933477,
#   'model_name': 'DaQJeR_00_Đen,28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1701747560,
#   'submit_time': 1701747560},
#  {'cmtid': 13977002116,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:xanh\nĐúng với mô tả:khá đúng\nChất liệu:vải jeans\n\nKhad là ok , quần giao khá nhanh , khá đẹp và chất lượng , mình mua với giá khá ok',
#   'modelid': 147132899679,
#   'model_name': 'H1QJeR_C3_Xanh Nhạt,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706064828,
#   'submit_time': 1706064828},
#  {'cmtid': 11606400185,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:jean\nMàu sắc:đẹp\nĐúng với mô tả:giống ảnh\n\nQuần đẹp lắm ạ, ko có ảnh ở ngoài nhưng mua lần thứ 3 rồi nên hiểu là quần đỉnh cỡ nào',
#   'modelid': 152890168762,
#   'model_name': 'DaQJeR_00_Đen,36',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1685295477,
#   'submit_time': 0},
#  {'cmtid': 12993894588,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:dung\nMàu sắc:xanh\nChất liệu:tot\n\nQuan ok qua tr lun a qua of my life and my life I have a very blessed family with you all \nS',
#   'modelid': 193100311376,
#   'model_name': 'DaQJeR_00_Xanh Nhạt,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1698253642,
#   'submit_time': 1698253642},
#  {'cmtid': 13885029598,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:bo\nMàu sắc:xám đen\nĐúng với mô tả:đúng\n\nĐã nhận được hàng . Quần rất đẹp mặc lên đẹp lắm , thật sự rất hài lòng về sản phẩm',
#   'modelid': 157132899611,
#   'model_name': 'H1QJeR_C3_Xám Đen,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705298607,
#   'submit_time': 1705298607},
#  {'cmtid': 11880086772,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng áo\nMàu sắc:đúng màu\nChất liệu:đúng như shop viết\n\nMặc vừa vặn, đẹp chất liệu tuyệt vời\nVừa với ví tiền 😂',
#   'modelid': 55673868568,
#   'model_name': 'H1QJeB_C3_Xám,27',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1688275468,
#   'submit_time': 0},
#  {'cmtid': 13944481567,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:ok\nMàu sắc:chuẩn\nĐúng với mô tả:đúng mô tả\n\nHàng giao đúng mẫu, đúng màu, đúng size\nHình ảnh mang tính chất nhận xu.',
#   'modelid': 152890168756,
#   'model_name': 'DaQJeR_00_Wash Nhạt,29',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705759061,
#   'submit_time': 1705759152},
#  {'cmtid': 14051951037,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': '[TB] Để đảm bảo an toàn phòng cháy, chữa cháy và thoát nạn trong mùa hanh khô, dịp Tết Nguyên đán Giáp Thìn 2024, Công an tỉnh Bắc Ninh khuyến cáo người dân, doanh nghiệp thực hiện tốt nội dung:\n1.Thường xuyên tự kiểm tra hệ thống, thiết bị điện, ngắt các thiết bị điện khi không sử dụng; kiểm soát nguồn lửa khi đun nấu, thắp hương, nến, đốt vàng mã, đốt rác...\n2.Chủ động mở thêm các lối thoát nạn dự phòng, tự trang bị bình chữa cháy, thang dây, dây hạ chậm, mặt nạ chống khói độc...\n3.Khi xảy ra cháy cần: Bình tĩnh, hô hoán, tìm cách thoát khỏi đám cháy nhanh nhất và gọi ngay đến số điện thoại 114; khi di chuyển cần: Hạ thấp cơ thể, dùng khăn, vải ướt bịt mồm, mũi để tránh ngạt khói...',
#   'modelid': 152890168765,
#   'model_name': 'DaQJeR_00_Wash Nhạt,31',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706680035,
#   'submit_time': 1706680035},
#  {'cmtid': 13221901681,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đenn\nĐúng với mô tả:đúng\nChất liệu:ok\n\nQua truyện Nữ thần Mặt Trời và Mặt Trăng chúng ta biết được cách nhận thức và lý giải nguồn gốc thế giới của người Việt xưa hết sức tự nhiên và vẫn lấy gốc là con người và những sự vật quen thuộc để giải thích. Câu chuyện lí giải những hiện tượng tự nhiên sảy ra trong cuộc sống hàng ngày liên quan đến Mặt Trời và Mặt Trăng. Qua đó khẳng định rằng mỗi sự việc xuất hiện xuất hiện trên Trái Đất đều có nguồn gốc rõ ràng. Vậy sau đây là 3 bài văn nghị luận phân tích đánh giá truyện Nữ thần Mặt Trời và Mặt Trăng mời các bạn cùng theo dõi',
#   'modelid': 152890168768,
#   'model_name': 'DaQJeR_00_Wash Đen,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1700061809,
#   'submit_time': 1700061809},
#  {'cmtid': 13333969838,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chủ đề: Nhà sàn Việt Bắc: Nhà sàn Việt Bắc tiếp tục trở thành xu hướng của kiến trúc dân dã tại Việt Nam vào năm 2023. Với thiết kế độc đáo và kỹ thuật hoàn mỹ, các công trình nhà sàn Việt Bắc ngày càng được nhiều gia đình lựa chọn. Những ngôi nhà sàn này không chỉ đẹp mắt, tiết kiệm chi phí xây dựng mà còn mang lại không gian sống ấm cúng, gần gũi với thiên nhiên. Việc ứng dụng kỹ thuật hiện đại vào xây dựng nhà sàn Việt Bắc đã tạo ra những sản phẩm đạt chất lượng cao và bền đẹp.',
#   'modelid': 115789933478,
#   'model_name': 'DaQJeR_R4_Wash Đậm,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1700921589,
#   'submit_time': 1700921589},
#  {'cmtid': 13979563599,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đen\nChất liệu:vải\nĐúng với mô tả:đúng\n\nKhóa học bồi dưỡng kỹ năng số về “Thanh toán không dùng tiền mặt và an toàn thông tin trên môi trường số” là cơ sở để phục vụ đánh giá Chỉ số Chuyển đổi số (DTI) của tỉnh. Đồng thời, sử dụng để đánh giá, chấm điểm DTI năm 2023 của các sở, ban, ngành; UBND các huyện, thị xã, thành phố và UBND các xã, phường, thị trấn trên toàn tỉnh.\n\nĐể tham gia khoá học, công dân phải truy cập vào chuyên trang Chuyển đổi số',
#   'modelid': 115789933484,
#   'model_name': 'DaQJeR_00_Đen,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706080391,
#   'submit_time': 1706080391},
#  {'cmtid': 13984988649,
#   'itemid': 9060816021,
#   'rating_star': 3,
#   'comment': 'Quần chưa mặc lần nào mà túi đã thế này đây \nMay ẩu',
#   'modelid': 193100311374,
#   'model_name': 'DaQJeR_00_Wash Vàng,28',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706109842,
#   'submit_time': 1707275726},
#  {'cmtid': 14010591723,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:ok\nMàu sắc:ok\nChất liệu:ok\n\nTuyệt vời với những con người cùng nhau xây dựng văn hoá.\nThực ra khách hàng cũng là người sẽ tham gia văn hoá của tổ chức bạn. Và nếu họ hoà nhập được nó và sống với nó. Thì văn hoá đó sẽ tiếp tục phát triển.\nChúc mừng Tùng Sơn Nguyễn & Coach Trần Hồng Quân\n#byebeo',
#   'modelid': 115789933480,
#   'model_name': 'DaQJeR_00_Đen,36',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706335079,
#   'submit_time': 1706335079},
#  {'cmtid': 13090988791,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:đen\nChất liệu:không biết 🤣\nĐúng với mô tả:đúng\n\nHay quá đi mất rồi vãi ò ra ngoài cổng thanh toán anh em nào có được một cái tội nghiệp cho học sinh giỏi k pk không biết nữa vui vẻ \nNên mua nha mấy ní',
#   'modelid': 152890168753,
#   'model_name': 'DaQJeR_00_Wash Đen,29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1699075536,
#   'submit_time': 1699075536},
#  {'cmtid': 14075311357,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:như hìnhh\nChất liệu:dày\nMàu sắc:xanh bạc\n\nuầy công nhận xinhh xĩu các bác ơi, cầm rất nặng tayy nè đi học hay đi chơi đều rất phù hợp.rất xuất sắc nhe ưng dữ lắm quả thật kh làm\ntui thất vọng',
#   'modelid': 152890168749,
#   'model_name': 'DaQJeR_00_Wash Nhạt,28',
#   'filter': 5,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706853695,
#   'submit_time': 1706853695},
#  {'cmtid': 13590523582,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:re\nMàu sắc:den\nĐúng với mô tả:ok\n\nQuần ổn với giá tiền , mua lần này lần 2 rồi , mặc khá ok , ra mẫu mới sẽ tiếp tục ủng hộ shop , rate 5*',
#   'modelid': 152890168753,
#   'model_name': 'DaQJeR_00_Wash Đen,29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1702867597,
#   'submit_time': 1702867597},
#  {'cmtid': 14406050609,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đẹp\nChất liệu:được\nMàu sắc:xanh\n\nĐẹp lắm rẻ nên mua cho con đi chơi vui không ạ không em có gì em nói gì nữa đâu anh ơi có',
#   'modelid': 152890168754,
#   'model_name': 'DaQJeR_00_Wash Nhạt,32',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1709632290,
#   'submit_time': 1709632290},
#  {'cmtid': 11705311905,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng\nChất liệu:hong biết\nMàu sắc:xanh đậm\n\nChào mừng bạn đến với bảng nhớ tạm của Gboard, bất kỳ văn bản nào bạn sao chép sẽ được lưu tại đây.',
#   'modelid': 152890168761,
#   'model_name': 'H3QJeB_00_Xanh Sky,36',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1686366288,
#   'submit_time': 0},
#  {'cmtid': 12540201893,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quần đẹp dầy nhưng rất rộng có thể cân nhắc xuống 1 size so với cân nặng chiều cao, quần giá này mà chất lượng rất oke đáng thử nha 😘',
#   'modelid': 152890168767,
#   'model_name': 'DaQJeR_00_Wash Đen,34',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1694361494,
#   'submit_time': 1694361494},
#  {'cmtid': 11963410400,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:Đúng\nChất liệu:Vải\nMàu sắc:Xanh sky\n\nĐúng với mô tả quần đẹp lắm mọi người lần sau sẽ ủng hộ shop tiếp mua 3 lần rồi ưng lắm=)))))',
#   'modelid': 115789933485,
#   'model_name': 'H1QJeB_C3_Xanh Sky,27',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1689068104,
#   'submit_time': 0},
#  {'cmtid': 15025383529,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng đẹp\nChất liệu:jean\nMàu sắc:bạc\n\nmua cho ngiu nên hong biết nma đẹp lắm nha cầm nặng tay nữa nên mua nhaaaaa',
#   'modelid': 152890168756,
#   'model_name': 'DaQJeR_00_Wash Nhạt,29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1714362768,
#   'submit_time': 1714362768},
#  {'cmtid': 13936869862,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu sắc:ok\nChất liệu:ok\nĐúng với mô tả:ok\n\nOk được biết rằng các em không có nhiều năm trước đó là người ta không phải có một người dân',
#   'modelid': 152890168750,
#   'model_name': 'DaQJeR_00_Wash Nhạt,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705712911,
#   'submit_time': 1705712911},
#  {'cmtid': 13864156907,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đúng mô tả\nMàu sắc:đen\nChất liệu:jeans\n\nMua nhiều lần hàng của shop rồi\nMong shop ra nhiều mẫu mới sz to như vậy',
#   'modelid': 152890168762,
#   'model_name': 'DaQJeR_00_Wash Đen,36',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705124461,
#   'submit_time': 1705124461},
#  {'cmtid': 11612158030,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:quần jeans\nĐúng với mô tả:quần đẹp nha\nMàu sắc:đen\n\nquần rất chi là đẹp luôn rất ưng ạ\nh.ảnh vd mang tính chất nhận xu',
#   'modelid': 152890168757,
#   'model_name': 'DaQJeR_00_Đen,28',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1685359773,
#   'submit_time': 0},
#  {'cmtid': 14096280570,
#   'itemid': 9060816021,
#   'rating_star': 5,
# ...
#   'submit_time': 1694810013},
#  {'cmtid': 12420516032,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:giống mô tả\nMàu sắc:màu xanh\nChất liệu:vải đẹp\n\nQuần ống đứng, mặc thoải mái co giãn tốt',
#   'modelid': 115789933478,
#   'model_name': 'H1QJeB_C3_Xanh Nhạt,30',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1693300246,
#   'submit_time': 1693300246},
#  {'cmtid': 11985781259,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Màu sắc:xám\n\nđẹp nha',
#   'modelid': 115789933484,
#   'model_name': 'H1QJeB_C3_Xanh Nhạt,29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1689249310,
#   'submit_time': 0},
#  {'cmtid': 11767211993,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đẹp, nên mua',
#   'modelid': 152890168752,
#   'model_name': 'H3QJeB_00_Xanh Sky,35',
#   'filter': 3,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1686985487,
#   'submit_time': 0},
#  {'cmtid': 6536116802,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Vải tốt',
#   'modelid': 55673868563,
#   'model_name': 'Xanh,Size 30',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1636509313,
#   'submit_time': 0},
#  {'cmtid': 13960796462,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đẹp lắm ạ',
#   'modelid': 203100311194,
#   'model_name': 'DaQJeR_00_Wash Vàng,30',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705913341,
#   'submit_time': 1705913341},
#  {'cmtid': 8219655842,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Lộn quần',
#   'modelid': 55673868563,
#   'model_name': 'Xanh SPO,Size 30',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1651122495,
#   'submit_time': 0},
#  {'cmtid': 11672575782,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Ko giống hình,bị bạc màu',
#   'modelid': 55673868569,
#   'model_name': 'H3QJeB_C3_Xám,29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1686050098,
#   'submit_time': 0},
#  {'cmtid': 6635198582,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Bok',
#   'modelid': 55673868568,
#   'model_name': 'Xanh,Size 27',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1637202478,
#   'submit_time': 0},
#  {'cmtid': 7521339679,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'quần đẹp ạ !',
#   'modelid': 55673868562,
#   'model_name': 'Xanh,Size 28',
#   'filter': 3,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1645152498,
#   'submit_time': 0},
#  {'cmtid': 5174796740,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'quan',
#   'modelid': 55673868563,
#   'model_name': 'Xanh,Size 30',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1624510666,
#   'submit_time': 0},
#  {'cmtid': 6501944229,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quá o\nK',
#   'modelid': 55673868565,
#   'model_name': 'Xanh,Size 33',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1636167041,
#   'submit_time': 0},
#  {'cmtid': 5307016071,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Mặc khá ổn',
#   'modelid': 55673868567,
#   'model_name': 'Xanh,Size 36',
#   'filter': 5,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1625720484,
#   'submit_time': 0},
#  {'cmtid': 7781694019,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quần đẹp lắmi',
#   'modelid': 55673868562,
#   'model_name': 'Xanh SPO,Size 28',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1647508330,
#   'submit_time': 0},
#  {'cmtid': 6894345431,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Rất chi là okayyy',
#   'modelid': 55673868563,
#   'model_name': 'Xanh,Size 30',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1639457393,
#   'submit_time': 0},
#  {'cmtid': 7782028006,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Ok',
#   'modelid': 115789933477,
#   'model_name': 'Xanh LV_3S,Size 28',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1647510110,
#   'submit_time': 0},
#  {'cmtid': 5163207113,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Nên mua mọi người ơi👍🏻',
#   'modelid': 55673868568,
#   'model_name': 'Xanh,Size 27',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1624412568,
#   'submit_time': 0},
#  {'cmtid': 8396117368,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'ok',
#   'modelid': 115789933478,
#   'model_name': 'Xanh LV_3S,Size 30',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1652777341,
#   'submit_time': 0},
#  {'cmtid': 13640588640,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:tốt\nMàu sắc:đep',
#   'modelid': 152890168766,
#   'model_name': 'DaQJeR_00_Wash Đen,31',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1703224638,
#   'submit_time': 1703224638},
#  {'cmtid': 7722644386,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quá xuất sắc chất lượng',
#   'modelid': 152890168766,
#   'model_name': 'Đen Paileys,Size 31',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1646969694,
#   'submit_time': 0},
#  {'cmtid': 13970094712,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Font quần rất đẹp',
#   'modelid': 152890168750,
#   'model_name': 'DaQJeR_00_Wash Nhạt,30',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705996993,
#   'submit_time': 1705996993},
#  {'cmtid': 13591893414,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'shop tuyệt vời',
#   'modelid': 193100311377,
#   'model_name': 'DaQJeR_00_Wash Đậm,34',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1702874605,
#   'submit_time': 1702874605},
#  {'cmtid': 6949324123,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Shop uy tín',
#   'modelid': 55673868570,
#   'model_name': 'Xanh,Size 31',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1639795157,
#   'submit_time': 0},
#  {'cmtid': 5892622596,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Shop nhiệt tình',
#   'modelid': 55673868565,
#   'model_name': 'Xanh,Size 33',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1630900980,
#   'submit_time': 0},
#  {'cmtid': 13255845100,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu đẹp',
#   'modelid': 193100311374,
#   'model_name': 'DaQJeR_00_Wash Đậm,28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1700301168,
#   'submit_time': 1700301168},
#  {'cmtid': 12593377780,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Mẫu đẹp',
#   'modelid': 55673868564,
#   'model_name': 'H1QJeB_C3_Xám,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1694777647,
#   'submit_time': 1694777647},
#  {'cmtid': 14231060434,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Giống trên ảnh 70-80% thôi mọi người nên cân nhắc',
#   'modelid': 152890168757,
#   'model_name': 'DaQJeR_00_Wash Đen,28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1708248039,
#   'submit_time': 1708248039},
#  {'cmtid': 14775766941,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:100đ không có nhưng nha',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Wash Đen,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1712198121,
#   'submit_time': 1712198121},
#  {'cmtid': 15610947086,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Nên mua',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Wash Đen,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1719209582,
#   'submit_time': 1719209582},
#  {'cmtid': 6096931364,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Úm ba la a la ba trap 123',
#   'modelid': 55673868563,
#   'model_name': 'Xanh,Size 30',
#   'filter': 5,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1632568019,
#   'submit_time': 0},
#  {'cmtid': 14807306615,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Sẽ mua lại lần 2 👍',
#   'modelid': 152890168753,
#   'model_name': 'DaQJeR_00_Wash Đen,29',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1712387504,
#   'submit_time': 1712387504},
#  {'cmtid': 15326768741,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Sản phẩm tốt',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Wash Đen,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1716883508,
#   'submit_time': 1716883508},
#  {'cmtid': 15325097337,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Sản phẩm tốt',
#   'modelid': 157132899616,
#   'model_name': 'H1QJeR_C3_Xám Đen,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1716873058,
#   'submit_time': 1716873058},
#  {'cmtid': 12876635863,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Giống ảnh! Khá ổn so với giá',
#   'modelid': 152890168758,
#   'model_name': 'DaQJeR_00_Wash Đen,30',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1697310135,
#   'submit_time': 1697310135},
#  {'cmtid': 15222263842,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đẹp lắm 😍😘',
#   'modelid': 217297411599,
#   'model_name': 'DaQJeR_0_Wash Đen V1,28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1715945764,
#   'submit_time': 1715945764},
#  {'cmtid': 5141901873,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Hơi mỏng anh em nhé ,',
#   'modelid': 55673868564,
#   'model_name': 'Xanh,Size 32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1624196980,
#   'submit_time': 0},
#  {'cmtid': 15003672052,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Chất liệu:i\nĐúng với mô tả:love\nMàu sắc:u\n\nKkk',
#   'modelid': 152890168765,
#   'model_name': 'DaQJeR_00_Wash Nhạt,31',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1714153505,
#   'submit_time': 1714153505},
#  {'cmtid': 13338414273,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'hơi ok mà cx ok :)',
#   'modelid': 115789933482,
#   'model_name': 'DaQJeR_00_Đen,31',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1700976953,
#   'submit_time': 1700976953},
#  {'cmtid': 8935154843,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đẹp lắm luôn á ae',
#   'modelid': 152890168766,
#   'model_name': 'DaQJeR_04_Đen·,31',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1657532995,
#   'submit_time': 0},
#  {'cmtid': 12884903485,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Hàng đẹp giống hình',
#   'modelid': 152890168749,
#   'model_name': 'H3QJeB_00_Xanh Retro,28',
#   'filter': 7,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1697371135,
#   'submit_time': 1697371135},
#  {'cmtid': 13880309235,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Đúng với mô tả:đẹp rẻ',
#   'modelid': 55673868562,
#   'model_name': 'DaQJeR_00_Xanh Nhạt,28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1705247557,
#   'submit_time': 1705247557},
#  {'cmtid': 12403146362,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'đẹp đáng tiền nha mng',
#   'modelid': 152890168757,
#   'model_name': 'DaQJeR_00_Wash Đen,28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1693134672,
#   'submit_time': 1693134672},
#  {'cmtid': 14886681300,
#   'itemid': 9060816021,
#   'rating_star': 1,
#   'comment': 'Không đúng màu',
#   'modelid': 152890168754,
#   'model_name': 'DaQJeR_00_Wash Nhạt,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1713156546,
#   'submit_time': 1713159303},
#  {'cmtid': 12635091456,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Nên tham khảo trang này',
#   'modelid': 152890168756,
#   'model_name': 'H3QJeB_00_Xanh Retro,29',
#   'filter': 1,
#   'anonymous': True,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1695196104,
#   'submit_time': 1695196104},
#  {'cmtid': 12038150940,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Không đúng với mẫu đặt',
#   'modelid': 152890168766,
#   'model_name': 'DaQJeR_00_Đen,31',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1689762991,
#   'submit_time': 0},
#  {'cmtid': 14418155164,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Màu khác trong ảnh',
#   'modelid': 115789933477,
#   'model_name': 'DaQJeR_00_Đen,28',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1709713738,
#   'submit_time': 1709780593},
#  {'cmtid': 12230251473,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'ko có j để tả',
#   'modelid': 115789933484,
#   'model_name': 'H1QJeB_C3_Xanh Nhạt,29',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1691644103,
#   'submit_time': 0},
#  {'cmtid': 14846410327,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Sản phẩm tốt',
#   'modelid': 152890168756,
#   'model_name': 'DaQJeR_00_Wash Nhạt,29',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1712667896,
#   'submit_time': 1712667896},
#  {'cmtid': 7305331127,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Hàng đẹp như ý',
#   'modelid': 55673868569,
#   'model_name': 'Xanh,Size 29',
#   'filter': 3,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1643034540,
#   'submit_time': 0},
#  {'cmtid': 5207080150,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'không giống hình',
#   'modelid': 55673868569,
#   'model_name': 'Xanh,Size 29',
#   'filter': 7,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1624800474,
#   'submit_time': 0},
#  {'cmtid': 14525589594,
#   'itemid': 9060816021,
#   'rating_star': 4,
#   'comment': 'Chưa hài lòng',
#   'modelid': 152890168755,
#   'model_name': 'DaQJeR_00_Wash Nhạt,27',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1710481896,
#   'submit_time': 1710481896},
#  {'cmtid': 14134988585,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quần đẹp(ưng 🤩ྀི )',
#   'modelid': 203100311197,
#   'model_name': 'DaQJeR_00_Wash Vàng,29',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1707294672,
#   'submit_time': 1707294672},
#  {'cmtid': 6430954507,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quần xinhh lắm ah',
#   'modelid': 55673868563,
#   'model_name': 'Xanh,Size 30',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1635480094,
#   'submit_time': 0},
#  {'cmtid': 14041326227,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Hàng giống mô tả',
#   'modelid': 152890168763,
#   'model_name': 'DaQJeR_00_Wash Đen,32',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1706592981,
#   'submit_time': 1706592981},
#  {'cmtid': 6721511196,
#   'itemid': 9060816021,
#   'rating_star': 5,
#   'comment': 'Quần hơi chật xíu',
#   'modelid': 55673868568,
#   'model_name': 'Xanh,Size 27',
#   'filter': 1,
#   'anonymous': False,
#   'origin_region': 'vn',
#   'region': 'VN',
#   'ctime': 1637906880,
#   'submit_time': 0},
#  ...]
